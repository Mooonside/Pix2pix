# %%
import sys
sys.path.insert(0, './gluon-cv/')

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt`
import numpy as np
# %matplotlib inline

from datasets.fascades import Fascades

# %%
datasets = Fascades(root='/home/chenyifeng/pix2pix/datasets/facades/', 
                    split='train', 
                    mode='train', 
                    crop_size=256)

# %%
img, mask = datasets[0]
plt.imshow(mask.asnumpy().astype(np.uint8))
